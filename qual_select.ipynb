# %% [markdown]
# GENETATE QUALITATIVE TABLE

# %% [markdown]
# import Dependencies

# %%
# needed libraries
import pandas as pd
import numpy as np
from dataset_dir import stata_dir
from dataset_dir import excel_dir
import os
import seaborn as sns
import datetime
date_today= datetime.date.today()
pd.io.formats.excel.ExcelFormatter.header_style = None
pd.options.display.max_rows = None
pd.options.display.max_columns = None
r=pd.read_stata(stata_dir()+"Teamup_Women_Dataset_cleanv4.dta",convert_categoricals=False)
print("Configuration Complete!")
# Out:
# Configuration Complete!

# %%
data=r.copy()

# %%
import pyreadstat

# %%
df,meta= pyreadstat.read_dta(stata_dir()+"Teamup_Women_Dataset_cleanv4.dta")

# %%
df.columns
# Out:
# Index(['starttime', 'endtime', 'deviceid', 'devicephonenum', 'today', 'level1',
#        'level2_cal', 'level2', 'level3_cal', 'level3',
#        ...
#        'gpslatitude', 'gpslongitude', 'gpsaltitude', 'gpsaccuracy', 'result',
#        'observation', 'audit', 'instanceid', 'instancename', 'key'],
#       dtype='object', length=10400)

# %% [markdown]
# Import report data

# %%
consistent_user=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Consistent User(more frequent)")
concurrent_user=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Concurrent User(1mth & 2-6mths)")
stopper=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Stoppers")
switcher=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Switchers")

# %%
s1=consistent_user["Respondent ID"]
s2=concurrent_user["Respondent ID"]
s3=stopper["Respondent ID"]
s4=switcher["Respondent ID"]
ids=[]
prof=[]
husband=[]
phone1=[]
phone2=[]
lga=[]
ward=[]
head=[]
gpslat=[]
gpslong=[]
gpsalt=[]
gpsacc=[]




choices=pd.read_excel("lgas.xlsx")


for i in s1:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s2:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s3:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s4:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
        
        
for i in ids:
    if(i in s1.values):
        prof.append("Consistent User")
    elif(i in s2.values):
        prof.append("Concurrent User")
    elif(i in s3.values):
        prof.append("Stopper")
    else:
        prof.append("Switcher")
        
# display(y)
for i in ids:
    x=data[data['resp_select']==i]['husband_participate']
    husband.append(x.iloc[0])
# display(z)

for i in ids:
    x=data[data['resp_select']==i]['phn_1st']
    phone1.append(x.iloc[0])

for i in ids:
    x=data[data['resp_select']==i]['phn_2nd']
    x=x.iloc[0]
    x=str(x)
    
    phone2.append(x)
for i in ids:
    x=data[data['resp_select']==i]['level3']
    x=x.iloc[0]
    x=int(x)
    x=choices[choices["code"]==x]["decode"]
    x=x.iloc[0]
    lga.append(x)

for i in ids:
    x=data[data['resp_select']==i]['ward']
    x=x.iloc[0]
    x=str(x)
    
    ward.append(x)
for i in ids:
    x=data[data['resp_select']==i]['hh_name']
    x=x.iloc[0]
    x=str(x)
    
    head.append(x)
for i in ids:
    x=data[data['resp_select']==i]['gpslatitude']
    gpslat.append(x.iloc[0])
for i in ids:
    x=data[data['resp_select']==i]['gpslongitude']
    gpslong.append(x.iloc[0]) 
for i in ids:
    x=data[data['resp_select']==i]['gpsaltitude']
    gpsalt.append(x.iloc[0]) 
for i in ids:
    x=data[data['resp_select']==i]['gpsaccuracy']
    gpsacc.append(x.iloc[0]) 
    
pd.DataFrame({"Respondent ID":ids,"Profile":prof,"LGA":lga,"Ward":ward,"Household head":head,"Phone no1":phone1,"Phone no2":phone2})
# Out:
#     Respondent ID          Profile         LGA  \
# 0    AD1603401-F2  Consistent User  Mayo-Belwa
# 1    AD1207802-F2  Consistent User  Mayo-Belwa
# 2    AD1601001-F3  Consistent User  Mayo-Belwa
# 3    AD1303403-F2  Consistent User  Mayo-Belwa
# 4    AD1604402-F2  Consistent User  Mayo-Belwa
# 5    AD0202301-F2  Consistent User  Mayo-Belwa
# 6    AD3202501-F2  Consistent User        Song
# 7    AD3404001-F3  Consistent User  Mayo-Belwa
# 8    AD1105801-F2  Consistent User  Mayo-Belwa
# 9    AD0203502-F2  Consistent User  Mayo-Belwa
# 10   AD2101301-F2  Consistent User        Song
# 11   AD0402901-F2  Concurrent User  Mayo-Belwa
# 12   AD0600601-F2  Concurrent User  Mayo-Belwa
# 13   AD1000901-F2  Concurrent User  Mayo-Belwa
# 14   AD1000901-F2  Concurrent User  Mayo-Belwa
# 15   AD1204301-F3  Concurrent User  Mayo-Belwa
# 16   AD1803401-F2  Concurrent User        Song
# 17   AD3200601-F2  Concurrent User        Song
# 18   AD3200601-F2  Concurrent User        Song
# 19   AD3305601-F2  Concurrent User        Song
# 20   AD0205001-F2          Stopper  Mayo-Belwa
# 21   AD1604101-F2          Stopper  Mayo-Belwa
# 22   AD1000701-F2          Stopper  Mayo-Belwa
# 23   AD1404901-F2          Stopper  Mayo-Belwa
# 24   AD0603701-F2          Stopper  Mayo-Belwa
# 25  AD2502801-F12          Stopper        Song
# 26   AD0702001-F2          Stopper  Mayo-Belwa
# 27   AD1000701-F2          Stopper  Mayo-Belwa
# 28   AD1803801-F2         Switcher        Song
# 29   AD0303801-F2         Switcher  Mayo-Belwa
# 30   AD2506801-F2         Switcher        Song
# 31   AD2801201-F2         Switcher        Song
# 32   AD3000901-F2         Switcher        Song
# 33   AD2802102-F2         Switcher        Song
# 34   AD2500201-F2         Switcher        Song
#
#                               Ward         Household head  Phone no1  \
# 0                          NDIKONG         KABIRU BAMANGA        NaN
# 1                         MATAKAVA            MAHMUD MUSA        NaN
# 2                          NDIKONG         BELLO MOHAMMED        NaN
# 3                           KIBANG       ABDULRAZAQ SAIDU        NaN
# 4                          NDIKONG          IBRAHIM HAMZA        NaN
# 5                       TUDUN WADA             ALI YAYAJO        NaN
# 6                             PIKA              ZIRA SINI        NaN
# 7               UBAKKA/GOROBI WARD           ELSAMA JATAU        NaN
# 8   MARARABA TOLA MAYO FARANG WARD          UMARU  HAMIDU        NaN
# 9                       TUDUN WADA          JAMILU YAKUBU        NaN
# 10                           BAKKA            HARISU MUSA        NaN
# 11             UNGUWAR MALAN LADAN    ABDULKADIR ABUBAKAR        NaN
# 12             UNGUWAR WAKILI BUBA      IBRAHIM BABA INNA        NaN
# 13  SEBORE AHMADU/MAYO FARANG WARD           USMANU UMARU        NaN
# 14  SEBORE AHMADU/MAYO FARANG WARD           USMANU UMARU        NaN
# 15                        MATAKAVA        SALMUNA SOLOMON        NaN
# 16                      JAURO TUDU            UASMAN BUBA        NaN
# 17                            PIKA             LUKA TUMBA        NaN
# 18                            PIKA             LUKA TUMBA        NaN
# 19                         DABAGHI             MUSA ADAMU        NaN
# 20                      TUDUN WADA         FLORENCE GARGA        NaN
# 21                         NDIKONG          ADAMU IBRAHIM        NaN
# 22       SEBORE AHMADU MAYO FARANG           DAUDA MODIBO        NaN
# 23                           KOLEN         DAHIRU IBRAHIM        NaN
# 24             UNGUWAR WAKILI BUBA      AWAL UMAR BABANYA        NaN
# 25                           NGAWA       MOHAMMED DANJUMA        NaN
# 26                    UNGUWAR FADA  MOHAMMED KABIRU GARBA        NaN
# 27       SEBORE AHMADU MAYO FARANG           DAUDA MODIBO        NaN
# 28                      JAURO TUDU            BITRUS BUBA        NaN
# 29                 UNGUWAR YELWA A   ABDULMUMINI DANJUMMA        NaN
# 30                           NGAWA         HUSSAINI NANLE        NaN
# 31                          DABERE        ZUBAIRU DANLADI        NaN
# 32                        GADAMAYO        AUWAL ABDULLAHI        NaN
# 33                          DABERE         DAHIRU HAMMAWA        NaN
# 34                           NGAWA         USMAN THANKGOD        NaN
#
#        Phone no2
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
# 5            nan
# 6            nan
# 7            nan
# 8            nan
# 9   9016865739.0
# 10           nan
# 11           nan
# 12           nan
# 13           nan
# 14           nan
# 15           nan
# 16           nan
# 17  9075884803.0
# 18  9075884803.0
# 19           nan
# 20           nan
# 21           nan
# 22           nan
# 23           nan
# 24           nan
# 25           nan
# 26           nan
# 27           nan
# 28           nan
# 29           nan
# 30           nan
# 31           nan
# 32  8065157790.0
# 33           nan
# 34           nan

# %%
for i,j in enumerate(consistent_user.columns):
    print(f"{i} ==> {j}")
# Out:
# 0 ==> Index Strategy Used
# 1 ==> Respondent ID
# 2 ==> Used Index Strategy with other strategy
# 3 ==> Used more than 1 strategy
# 4 ==> Used index strategy throughout 6 month period(q211 and q215)
# 5 ==> Used index strategy throughout 6 month period(q211 and q216)
# 6 ==> Used more than 1 strategy in last 1 month (q211a_c_count > 1)
# 7 ==> Used more than 1 strategy in last 2- 6 months (q216_ac_count > 1)
# 8 ==> Used any strategy in the last one month (q209a)
# 9 ==> Used any strategy in the last 2-6 month (q209a)
# 10 ==> Used any strategy in the last 2-6 months (q210)
# 11 ==> How often have you used this strategy in the past 6 months (q220-q223)a_x
# 12 ==> Used index stragegy in last 1 month (q211_calx=1)
# 13 ==> Used index stragegy in last 2-6 months (q216_calx=1)

# %%
for i in data.columns:
    if('ad' in i):print(i)
# Out:
# head_check

# %%
data.iloc[1].head(40)
# Out:
# starttime                Oct 5, 2022 11:30:15 AM
# endtime                  Oct 5, 2022 12:02:48 PM
# deviceid                collect:7b0e0NENVENrToWJ
# devicephonenum                               NaN
# today                                Oct 5, 2022
# level1                                         3
# level2_cal                                 State
# level2                                         8
# level3_cal                                   LGA
# level3                                        56
# level4                                      AD29
# your_name                                     79
# name_yesno                                     1
# name_typed
# tday                                         NaN
# date_yesno                                     1
# manual_date                                  NaN
# todaynow           2022-10-05T00:00:00.000+01:00
# structure_n                                   66
# structure                                     66
# hhid                                           2
# hhid_select                            AD2906602
# hhid_cal                               AD2906602
# consent                                        1
# respondent_sign                              NaN
# res_id                                        F2
# resp_select                         AD2906602-F2
# res_name                            AD2906602-F2
# ward                                      GUDURE
# hh_name                             ADAMU YAKUBU
# q12                                          1.0
# q13                                          2.0
# head_check                                   NaN
# q101                                        25.0
# q102                                 Nov 3, 1996
# ageyr                                       25.0
# agegreater                                   NaN
# q105                                         1.0
# q106                                         2.0
# q106_cal                               Secondary
# Name: 1, dtype: object

# %%
'AD1601001-F8' in s1.values
# Out:
# False

# %%
x=choices[choices["code"]==56]["decode"]
# x=x.iloc[0]
x
# Out:
# 56    Song
# Name: decode, dtype: object
