# %% [markdown]
# GENETATE QUALITATIVE TABLE

# %% [markdown]
# import Dependencies

# %%
# needed libraries
import pandas as pd
import numpy as np
from dataset_dir import stata_dir
from dataset_dir import excel_dir
import os
import seaborn as sns
import datetime
date_today= datetime.date.today()
pd.io.formats.excel.ExcelFormatter.header_style = None
pd.options.display.max_rows = None
pd.options.display.max_columns = None
r=pd.read_stata(stata_dir()+"Teamup_Women_Dataset_cleanv4.dta",convert_categoricals=False)
respondent_labels=pd.read_excel(excel_dir()+"teamup_women_name.xlsx")
interviewer_names=pd.read_excel(excel_dir()+"teamup_interviewers.xlsx")
print("Configuration Complete!")
# Out:
# Configuration Complete!

# %%
# Out:
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 79    Rejoice Matthias
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# ...
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 81    Ruth zakka
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 82    Safiya Bedan
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 70    Comfort Japheth Ebzan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 83    Sherifat Sanda
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 72    Elizabeth Yakubu
# Name: name, dtype: object
# 71    Daisy Love Benard
# Name: name, dtype: object
# 69    Agness Lawan
# Name: name, dtype: object
# 77    Nancy .D. Kassa
# Name: name, dtype: object
# 73    Erica Eric Kussiy
# Name: name, dtype: object
# 85    Yashene Aaron Kachalla
# Name: name, dtype: object
# 75    Justina Iliya
# Name: name, dtype: object
# 80    Ruth Luka Dodo
# Name: name, dtype: object
# 68    Agnes Jijiwa
# Name: name, dtype: object
# 76    Munyal James
# Name: name, dtype: object

# %%
interviewer_names=pd.read_excel(excel_dir()+"teamup_interviewers.xlsx")

# %%
r['resp_labels']=respondent_labels['res_name']
r['interviewer_labels']=interviewer_names['name']
# Out:
# C:\Users\Ayo\AppData\Local\Temp\ipykernel_14840\3455227350.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   r['resp_labels']=respondent_labels['res_name']
# C:\Users\Ayo\AppData\Local\Temp\ipykernel_14840\3455227350.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   r['interviewer_labels']=interviewer_names['name']

# %%
r.columns
# Out:
# Index(['starttime', 'endtime', 'deviceid', 'devicephonenum', 'today', 'level1',
#        'level2_cal', 'level2', 'level3_cal', 'level3',
#        ...
#        'gpsaltitude', 'gpsaccuracy', 'result', 'observation', 'audit',
#        'instanceid', 'instancename', 'key', 'resp_labels',
#        'interviewer_labels'],
#       dtype='object', length=10402)

# %%
data=r.copy()

# %%
import pyreadstat

# %%
df,meta= pyreadstat.read_dta(stata_dir()+"Teamup_Women_Dataset_cleanv4.dta")

# %%
df.columns
# Out:
# Index(['starttime', 'endtime', 'deviceid', 'devicephonenum', 'today', 'level1',
#        'level2_cal', 'level2', 'level3_cal', 'level3',
#        ...
#        'gpslatitude', 'gpslongitude', 'gpsaltitude', 'gpsaccuracy', 'result',
#        'observation', 'audit', 'instanceid', 'instancename', 'key'],
#       dtype='object', length=10400)

# %% [markdown]
# Import report data

# %%
consistent_user=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Consistent User(more frequent)")
concurrent_user=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Concurrent User(1mth & 2-6mths)")
stopper=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Stoppers")
switcher=pd.read_excel(excel_dir()+"AFIDEP_user_profiles_adamawa_JO_29Nov2022_v1.xlsx",sheet_name="Switchers")

# %%
s1=consistent_user["Respondent ID"]
s2=concurrent_user["Respondent ID"]
s3=stopper["Respondent ID"]
s4=switcher["Respondent ID"]
ids=[]
resp_name=[]
prof=[]
husband=[]
phone1=[]
phone2=[]
lga=[]
ward=[]
head=[]
gpslat=[]
gpslong=[]
gpsalt=[]
gpsacc=[]
interviewer=[]
date_of_interview=[]
good_time=[]
reinterview=[]
husband_concent=[]
observation=[]



choices=pd.read_excel("lgas.xlsx")


for i in s1:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s2:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s3:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
for i in s4:
    if(str(type(i))!="<class 'float'>"):
        ids.append(i)
        
        
for i in ids:
    if(i in s1.values):
        prof.append("Consistent User")
    elif(i in s2.values):
        prof.append("Concurrent User")
    elif(i in s3.values):
        prof.append("Stopper")
    else:
        prof.append("Switcher")
        
# display(y)
for i in ids:
    x=data[data['resp_select']==i]['husband_participate']
    husband.append(x.iloc[0])
# display(z)
for i in ids:
    x=data[data['resp_select']==i]['resp_labels']
    resp_name.append(x.iloc[0])
    
for i in ids:
    x=data[data['resp_select']==i]['phn_1st']
    phone1.append(x.iloc[0])

for i in ids:
    x=data[data['resp_select']==i]['phn_2nd']
    x=x.iloc[0]
    x=str(x)
    
    phone2.append(x)
for i in ids:
    x=data[data['resp_select']==i]['level3']
    x=x.iloc[0]
    x=int(x)
    x=choices[choices["code"]==x]["decode"]
    x=x.iloc[0]
    lga.append(x)

for i in ids:
    x=data[data['resp_select']==i]['ward']
    x=x.iloc[0]
    x=str(x)
    
    ward.append(x)
for i in ids:
    x=data[data['resp_select']==i]['husband_name']
    x=x.iloc[0]
    x=str(x)
    
    head.append(x)
for i in ids:
    x=data[data['resp_select']==i]['gpslatitude']
    gpslat.append(x.iloc[0])
for i in ids:
    x=data[data['resp_select']==i]['gpslongitude']
    gpslong.append(x.iloc[0]) 
for i in ids:
    x=data[data['resp_select']==i]['gpsaltitude']
    gpsalt.append(x.iloc[0]) 
for i in ids:
    x=data[data['resp_select']==i]['gpsaccuracy']
    gpsacc.append(x.iloc[0]) 
for i in ids:
    x=data[data['resp_select']==i]['your_name']
    interviewer.append(x.iloc[0])   
for i in ids:
    x=data[data['resp_select']==i]['provide_phn']
    reinterview.append(x.iloc[0])
for i in ids:
    x=data[data['resp_select']==i]['today']
    date_of_interview.append(x.iloc[0])  
for i in ids:
    x=data[data['resp_select']==i]['husband_schedule']
    x=x.iloc[0]
    good_time.append(x[-11:])
for i in ids:
    x=data[data['resp_select']==i]['husband_participate']
    husband_concent.append(x.iloc[0])      
for i in ids:
    x=data[data['resp_select']==i]['observation']
    observation.append(x.iloc[0])       

selection=pd.DataFrame({"Respondent ID":ids,
              "Respondent Name":resp_name,
              "Profile":prof,"LGA":lga,
              "Ward":ward,
              "Phone no1":phone1,
              "Phone no2":phone2,
              "Consent for re-interview":reinterview,
              "Concent for husband's Interview":husband_concent,
              "Respondent's husband":head,
              "Good time for Husband Interview":good_time,
              "GPS Latitude":gpslat,
              "GPS Longitude":gpslong,
              "GPS Altitude":gpsalt,
              "GPS Accuracy":gpsacc,
              "Interviewer Name":interviewer,
              "Date of Interview":date_of_interview})
selection = selection.replace(1,'Yes')
selection = selection.replace(0,'No')
temp=[]
for i in selection['Interviewer Name']:
    if i in interviewer_names['id']:
        x=interviewer_names[interviewer_names['id']==i]['name']
        temp.append(x.iloc[0])
selection['Interviewer Name']=temp
selection
# Out:
#     Respondent ID     Respondent Name          Profile         LGA  \
# 0    AD1603401-F2      FATIMA IBRAHIM  Consistent User  Mayo-Belwa
# 1    AD1207802-F2        AISHATU UMAR  Consistent User  Mayo-Belwa
# 2    AD1601001-F3      AISHA SULEIMAN  Consistent User  Mayo-Belwa
# 3    AD1303403-F2         AMINA BELLO  Consistent User  Mayo-Belwa
# 4    AD1604402-F2       SALAMATU HUDU  Consistent User  Mayo-Belwa
# 5    AD0202301-F2     FATIMA ABUBAKAR  Consistent User  Mayo-Belwa
# 6    AD3202501-F2     INKECHI ANYAEBU  Consistent User        Song
# 7    AD3404001-F3       SERAH ANTHONY  Consistent User  Mayo-Belwa
# 8    AD1105801-F2    HAS IYA ABUBAKAR  Consistent User  Mayo-Belwa
# 9    AD0203502-F2        DATSO ILLIYA  Consistent User  Mayo-Belwa
# 10   AD2101301-F2     BLESSING MARKUS  Consistent User        Song
# 11   AD0402901-F2       HOPE INNOCENT  Concurrent User  Mayo-Belwa
# 12   AD0600601-F2      TABITHA SAMUEL  Concurrent User  Mayo-Belwa
# 13   AD1000901-F2   ELIZABETH TANDAUS  Concurrent User  Mayo-Belwa
# 14   AD1000901-F2   ELIZABETH TANDAUS  Concurrent User  Mayo-Belwa
# 15   AD1204301-F3     PATIENCE YAKUBU  Concurrent User  Mayo-Belwa
# 16   AD1803401-F2        KHADIJA MUSA  Concurrent User        Song
# 17   AD3200601-F2       HALITA LEMUEL  Concurrent User        Song
# 18   AD3200601-F2       HALITA LEMUEL  Concurrent User        Song
# 19   AD3305601-F2      REBECCA ISHAYA  Concurrent User        Song
# 20   AD0205001-F2        HAUWA'U UMAR          Stopper  Mayo-Belwa
# 21   AD1604101-F2    GAWARDIKIM GBATO          Stopper  Mayo-Belwa
# 22   AD1000701-F2         PEACE YAUBA          Stopper  Mayo-Belwa
# 23   AD1404901-F2          HAFSAT ALI          Stopper  Mayo-Belwa
# 24   AD0603701-F2  HADIZA ABDULMUMINI          Stopper  Mayo-Belwa
# 25  AD2502801-F12   AISHATU ABDULLAHI          Stopper        Song
# 26   AD0702001-F2       ZAINAB HARUNA          Stopper  Mayo-Belwa
# 27   AD1000701-F2         PEACE YAUBA          Stopper  Mayo-Belwa
# 28   AD1803801-F2       HADIZA HAMISU         Switcher        Song
# 29   AD0303801-F2         NAFISA ISAH         Switcher  Mayo-Belwa
# 30   AD2506801-F2      ADAMA SHUWAIBU         Switcher        Song
# 31   AD2801201-F2      WADUNSO ELISHA         Switcher        Song
# 32   AD3000901-F2    AMINCHI HANANIYA         Switcher        Song
# 33   AD2802102-F2       DEBORAH DAVID         Switcher        Song
# 34   AD2500201-F2         SARAH ISAAC         Switcher        Song
#
#                               Ward  Phone no1     Phone no2  \
# 0                          NDIKONG        NaN           nan
# 1                         MATAKAVA        NaN           nan
# 2                          NDIKONG        NaN           nan
# 3                           KIBANG        NaN           nan
# 4                          NDIKONG        NaN           nan
# 5                       TUDUN WADA        NaN           nan
# 6                             PIKA        NaN           nan
# 7               UBAKKA/GOROBI WARD        NaN           nan
# 8   MARARABA TOLA MAYO FARANG WARD        NaN           nan
# 9                       TUDUN WADA        NaN  9016865739.0
# 10                           BAKKA        NaN           nan
# 11             UNGUWAR MALAN LADAN        NaN           nan
# 12             UNGUWAR WAKILI BUBA        NaN           nan
# 13  SEBORE AHMADU/MAYO FARANG WARD        NaN           nan
# 14  SEBORE AHMADU/MAYO FARANG WARD        NaN           nan
# 15                        MATAKAVA        NaN           nan
# 16                      JAURO TUDU        NaN           nan
# 17                            PIKA        NaN  9075884803.0
# 18                            PIKA        NaN  9075884803.0
# 19                         DABAGHI        NaN           nan
# 20                      TUDUN WADA        NaN           nan
# 21                         NDIKONG        NaN           nan
# 22       SEBORE AHMADU MAYO FARANG        NaN           nan
# 23                           KOLEN        NaN           nan
# 24             UNGUWAR WAKILI BUBA        NaN           nan
# 25                           NGAWA        NaN           nan
# 26                    UNGUWAR FADA        NaN           nan
# 27       SEBORE AHMADU MAYO FARANG        NaN           nan
# 28                      JAURO TUDU        NaN           nan
# 29                 UNGUWAR YELWA A        NaN           nan
# 30                           NGAWA        NaN           nan
# 31                          DABERE        NaN           nan
# 32                        GADAMAYO        NaN  8065157790.0
# 33                          DABERE        NaN           nan
# 34                           NGAWA        NaN           nan
#
#    Consent for re-interview Concent for husband's Interview  \
# 0                       Yes                              No
# 1                       Yes                              No
# 2                       Yes                              No
# 3                       Yes                              No
# 4                       Yes                              No
# 5                       Yes                             Yes
# 6                       Yes                             Yes
# 7                        No                              No
# 8                       Yes                             Yes
# 9                       Yes                             Yes
# 10                      Yes                             Yes
# 11                      Yes                              No
# 12                      Yes                             Yes
# 13                       No                              No
# 14                       No                              No
# 15                      Yes                             NaN
# 16                      Yes                              No
# 17                      Yes                             Yes
# 18                      Yes                             Yes
# 19                       No                              No
# 20                      Yes                             NaN
# 21                      Yes                              No
# 22                      Yes                              No
# 23                      Yes                             Yes
# 24                      Yes                              No
# 25                      Yes                             NaN
# 26                      Yes                              No
# 27                      Yes                              No
# 28                      Yes                              No
# 29                      Yes                             Yes
# 30                      Yes                              No
# 31                      Yes                              No
# 32                      Yes                             Yes
# 33                      Yes                             Yes
# 34                       No                              No
#
#     Respondent's husband Good time for Husband Interview  GPS Latitude  \
# 0                                                             9.168752
# 1                                                             8.763727
# 2                                                             9.167978
# 3                                                             8.750436
# 4                                                             9.169433
# 5             ALI YAYAJO                      2:06:00 PM      9.045957
# 6              ZIRA SINI                      5:00:00 PM     10.021035
# 7                                                             9.198790
# 8           UMARU HAMIDU                      8:48:00 AM      8.917504
# 9          JAMILU YAKUBU                      7:20:00 AM      9.046135
# 10           HARISU MUSA                      2:00:00 PM      9.779250
# 11                                                            9.052182
# 12     IBRAHIM BABA INNA                      5:00:00 PM      9.059633
# 13                                                            8.908268
# 14                                                            8.908268
# 15                                                            8.762843
# 16                                                            9.653450
# 17            LUKA TUMBA                     12:00:00 PM     10.019594
# 18            LUKA TUMBA                     12:00:00 PM     10.019594
# 19                                                           10.025516
# 20                                                            9.044405
# 21                                                            9.169908
# 22                                                            8.908269
# 23        DAHIRU IBRAHIM                      8:16:00 PM      8.723822
# 24                                                            9.059758
# 25                                                            9.806643
# 26                                                            9.060389
# 27                                                            8.908269
# 28                                                            9.654122
# 29  ABDULMUMINI DANJUMMA                     10:00:00 AM      9.053553
# 30                                                            9.807989
# 31                                                            9.826480
# 32       AUWAL ABDULLAHI                      8:00:00 AM      9.831091
# 33        DAHIRU HAMMAWA                      5:00:00 PM      9.827131
# 34                                                            9.806414
#
#     GPS Longitude  GPS Altitude  GPS Accuracy        Interviewer Name  \
# 0       12.202621    226.399994         4.869   Comfort Japheth Ebzan
# 1       11.963523    479.299988         4.800   Comfort Japheth Ebzan
# 2       12.202791    254.100006         4.909   Comfort Japheth Ebzan
# 3       11.938126    497.700012         5.000   Comfort Japheth Ebzan
# 4       12.202355    208.000000         4.780   Comfort Japheth Ebzan
# 5       12.058406    301.500000         5.000         Nancy .D. Kassa
# 6       12.664150    488.200012         4.852          Ruth Luka Dodo
# 7       11.723292    319.200012         4.923       Daisy Love Benard
# 8       12.097558    392.799988         4.500           Justina Iliya
# 9       12.057809    330.500000         5.000         Nancy .D. Kassa
# 10      12.498761    320.899994         4.750            Safiya Bedan
# 11      12.056586    297.399994         4.954  Yashene Aaron Kachalla
# 12      12.054164    297.899994         4.500       Erica Eric Kussiy
# 13      12.115042    429.000000         4.955       Daisy Love Benard
# 14      12.115042    429.000000         4.955       Daisy Love Benard
# 15      11.964968    503.899994         4.811   Comfort Japheth Ebzan
# 16      12.556341    350.500000         4.994            Agness Lawan
# 17      12.661979    433.399994         5.000            Agnes Jijiwa
# 18      12.661979    433.399994         5.000            Agnes Jijiwa
# 19      12.659532    516.700012         5.000            Agnes Jijiwa
# 20      12.058298    293.200012         5.000         Nancy .D. Kassa
# 21      12.202456    227.199997         4.092   Comfort Japheth Ebzan
# 22      12.114856    434.200012         4.500           Justina Iliya
# 23      11.925698    520.700012         4.944   Comfort Japheth Ebzan
# 24      12.055354    276.500000         5.000       Erica Eric Kussiy
# 25      12.617175    319.000000         5.000          Sherifat Sanda
# 26      12.052444    256.100006         5.000       Erica Eric Kussiy
# 27      12.114856    434.200012         4.500           Justina Iliya
# 28      12.556169    344.100006         5.000          Sherifat Sanda
# 29      12.052811    320.399994         4.800  Yashene Aaron Kachalla
# 30      12.616333    315.500000         5.000          Sherifat Sanda
# 31      12.627254    331.399994         4.582            Munyal James
# 32      12.627026    328.500000         4.789            Agnes Jijiwa
# 33      12.626947    311.399994         4.500            Safiya Bedan
# 34      12.615494    308.799988         4.779          Sherifat Sanda
#
#    Date of Interview
# 0       Oct 20, 2022
# 1        Oct 7, 2022
# 2       Oct 22, 2022
# 3        Oct 9, 2022
# 4       Oct 20, 2022
# 5       Oct 15, 2022
# 6       Oct 22, 2022
# 7        Oct 8, 2022
# 8        Oct 3, 2022
# 9       Oct 17, 2022
# 10       Oct 1, 2022
# 11       Oct 4, 2022
# 12      Oct 16, 2022
# 13      Sep 30, 2022
# 14      Sep 30, 2022
# 15       Oct 5, 2022
# 16      Oct 15, 2022
# 17      Oct 22, 2022
# 18      Oct 22, 2022
# 19      Oct 23, 2022
# 20      Oct 17, 2022
# 21      Oct 20, 2022
# 22      Sep 30, 2022
# 23       Oct 1, 2022
# 24      Oct 15, 2022
# 25       Oct 3, 2022
# 26       Oct 6, 2022
# 27      Sep 30, 2022
# 28      Oct 16, 2022
# 29      Oct 27, 2022
# 30       Oct 4, 2022
# 31      Oct 15, 2022
# 32       Oct 1, 2022
# 33      Oct 16, 2022
# 34       Oct 4, 2022

# %%
for i,j in enumerate(consistent_user.columns):
    print(f"{i} ==> {j}")
# Out:
# 0 ==> Index Strategy Used
# 1 ==> Respondent ID
# 2 ==> Used Index Strategy with other strategy
# 3 ==> Used more than 1 strategy
# 4 ==> Used index strategy throughout 6 month period(q211 and q215)
# 5 ==> Used index strategy throughout 6 month period(q211 and q216)
# 6 ==> Used more than 1 strategy in last 1 month (q211a_c_count > 1)
# 7 ==> Used more than 1 strategy in last 2- 6 months (q216_ac_count > 1)
# 8 ==> Used any strategy in the last one month (q209a)
# 9 ==> Used any strategy in the last 2-6 month (q209a)
# 10 ==> Used any strategy in the last 2-6 months (q210)
# 11 ==> How often have you used this strategy in the past 6 months (q220-q223)a_x
# 12 ==> Used index stragegy in last 1 month (q211_calx=1)
# 13 ==> Used index stragegy in last 2-6 months (q216_calx=1)

# %%
for i in data.columns:
    if('ad' in i):print(i)
# Out:
# head_check

# %%
data.iloc[1].tail(40)
# Out:
# q417                                                         NaN
# q418                                                         NaN
# q419                                                         NaN
# q420                                                         NaN
# q421                                                         7.0
# q421b                                                       18.0
# q422                                                         1.0
# q423                                                         NaN
# q424a                                                        2.0
# q424b                                                        1.0
# q425a                                                        0.0
# q425b                                                        NaN
# q426                                                         1.0
# q427                                                         1.0
# q428                                                         1.0
# q429                                                         0.0
# q430                                                         0.0
# sum_child                                                    0.0
# q431                                                         5.0
# q432                                                        36.0
# provide_phn                                                  1.0
# phn_1st                                                      NaN
# provide_phn2                                                 1.0
# phn_2nd                                             9033317882.0
# husband_participate                                          1.0
# husband_name                                        ADAMU YAKUBU
# husband_schedule                         Oct 11, 2022 5:00:00 PM
# int_language                                                 8.0
# int_language_oth                                             NaN
# gpslatitude                                             9.828676
# gpslongitude                                           12.621776
# gpsaltitude                                           375.299988
# gpsaccuracy                                                4.935
# result                                                         1
# observation                                                 NILL
# audit                                                  audit.csv
# instanceid             uuid:a1975882-726e-4366-a9d5-cbb44ad868ce
# instancename                                TEAMUP: JAMILA ABDUL
# key                    uuid:a1975882-726e-4366-a9d5-cbb44ad868ce
# resp_labels                                    YANRUSIBEH SANUBA
# Name: 1, dtype: object

# %%
'AD1601001-F8' in s1.values
# Out:
# False

# %%
x=choices[choices["code"]==56]["decode"]
# x=x.iloc[0]
x
# Out:
# 56    Song
# Name: decode, dtype: object

# %%
good_time=[]
x=data[data['resp_select']=="AD3200601-F2"]['husband_schedule']
x=x.iloc[0]
good_time.append(x[-11:])
# Out:
# ['12:00:00 PM']
